# %%
import sys
sys.path.append('../src/')
from h5tools import *
import cv2
from scipy.special import erfinv
from scipy.special import erf
import pyopencl as cl
from pathlib import Path
import json
import tqdm as tqdm

# %matplotlib widget
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
### User Defined
### This should be the only thing that needs to defined
CONFIG_FILE_NAME = "config_IPA_NBH_A4.json" #"config_NPS_2_data_090825.json" #"config_B10_2_A7_data_091825.json" #"config_NPS_2_data_090825.json" #"config_B10_2_A7_data_071525.json"

### Scan In Config You Want to PreProcess ### 
Scan = 73
